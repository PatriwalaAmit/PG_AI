# %% [markdown]
# ## Amazon Movie & TV Ratings

# %% [markdown]
# #### Data Dictionary
# UserID – 4848 customers who provided a rating for each movie
#
# Movie 1 to Movie 206 – 206 movies for which ratings are provided by 4848 distinct users
#
# Data Considerations
#
# - All the users have not watched all the movies and therefore, all movies are not rated. These missing values are represented by NA.
# - Ratings are on a scale of -1 to 10 where -1 is the least rating and 10 is the best.
#
# Analysis Task
#
# Exploratory Data Analysis:
#
# - Which movies have maximum views/ratings?
# - What is the average rating for each movie? Define the top 5 movies with the maximum ratings.
# - Define the top 5 movies with the least audience.
#
# Recommendation Model:
#
# Some of the movies hadn’t been watched and therefore, are not rated by the users. Netflix would like to take this as an opportunity and build a machine learning recommendation algorithm which provides the ratings for each of the users.
#
# - Divide the data into training and test data
# - Build a recommendation model on training data
# - Make predictions on the test data

# %%
import pandas as pd

# %%
data = pd.read_csv('~/MyWorkPython/data/Amazon_Movies_and_TV_Ratings.csv')

# %%
data.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 207 columns]

# %%
data.describe()
# Out:
#        Movie1  Movie2  Movie3  Movie4     Movie5  Movie6  Movie7  Movie8  \
# count     1.0     1.0     1.0     2.0  29.000000     1.0     1.0     1.0
# mean      5.0     5.0     2.0     5.0   4.103448     4.0     5.0     5.0
# std       NaN     NaN     NaN     0.0   1.496301     NaN     NaN     NaN
# min       5.0     5.0     2.0     5.0   1.000000     4.0     5.0     5.0
# 25%       5.0     5.0     2.0     5.0   4.000000     4.0     5.0     5.0
# 50%       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
# 75%       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
# max       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
#
#        Movie9  Movie10  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# count     1.0      1.0  ...  5.000000       2.0       1.0  8.000000  3.000000
# mean      5.0      5.0  ...  3.800000       5.0       5.0  4.625000  4.333333
# std       NaN      NaN  ...  1.643168       0.0       NaN  0.517549  1.154701
# min       5.0      5.0  ...  1.000000       5.0       5.0  4.000000  3.000000
# 25%       5.0      5.0  ...  4.000000       5.0       5.0  4.000000  4.000000
# 50%       5.0      5.0  ...  4.000000       5.0       5.0  5.000000  5.000000
# 75%       5.0      5.0  ...  5.000000       5.0       5.0  5.000000  5.000000
# max       5.0      5.0  ...  5.000000       5.0       5.0  5.000000  5.000000
#
#        Movie202  Movie203  Movie204   Movie205   Movie206
# count  6.000000       1.0  8.000000  35.000000  13.000000
# mean   4.333333       3.0  4.375000   4.628571   4.923077
# std    1.632993       NaN  1.407886   0.910259   0.277350
# min    1.000000       3.0  1.000000   1.000000   4.000000
# 25%    5.000000       3.0  4.750000   5.000000   5.000000
# 50%    5.000000       3.0  5.000000   5.000000   5.000000
# 75%    5.000000       3.0  5.000000   5.000000   5.000000
# max    5.000000       3.0  5.000000   5.000000   5.000000
#
# [8 rows x 206 columns]

# %% [markdown]
# ### Q1 Which movies have maximum views/ratings?

# %% [markdown]
# #### Logic 1 - getting the count using the describe

# %%
data.describe().T["count"].sort_values(ascending = False)[:10].to_frame()
# Out:
#            count
# Movie127  2313.0
# Movie140   578.0
# Movie16    320.0
# Movie103   272.0
# Movie29    243.0
# Movie91    128.0
# Movie92    101.0
# Movie89     83.0
# Movie158    66.0
# Movie108    54.0

# %% [markdown]
# #### Logic 2 based on the movie column data, we will get the Movie Name, Rating using Mean and No. Of Users

# %%
data_logic2 = pd.DataFrame(columns=['MovieId','MovieRating','NoOfUserRating'])

for id, value in enumerate(data.iloc[:,1:].columns):     
    data_logic2.loc[id,'MovieId'] = value
    data_logic2.loc[id,'MovieRating'] = round(data.loc[:,value].mean(),2)
    data_logic2.loc[id,'NoOfUserRating'] = data.loc[:,value].notnull().sum()

# now we have a new data with the Movie Id, Movie Rating and No Of User Rating
data_logic2.sort_values(by=['NoOfUserRating','MovieRating'], ascending=False)[:10]
# Out:
#       MovieId MovieRating NoOfUserRating
# 126  Movie127        4.11           2313
# 139  Movie140        4.83            578
# 15    Movie16        4.52            320
# 102  Movie103        4.56            272
# 28    Movie29        4.81            243
# 90    Movie91        4.58            128
# 91    Movie92        4.77            101
# 88    Movie89        4.58             83
# 157  Movie158        4.82             66
# 107  Movie108        4.67             54

# %% [markdown]
# ### Q2 What is the average rating for each movie? Define the top 5 movies with the maximum ratings.

# %% [markdown]
# #### Logic 1

# %%
data.describe().T["count"].sort_values(ascending = False)[:5].to_frame()
# Out:
#            count
# Movie127  2313.0
# Movie140   578.0
# Movie16    320.0
# Movie103   272.0
# Movie29    243.0

# %% [markdown]
# #### Logic 2

# %%
data_logic2.sort_values(by=['NoOfUserRating','MovieRating'], ascending=False).head()
# Out:
#       MovieId MovieRating NoOfUserRating
# 126  Movie127        4.11           2313
# 139  Movie140        4.83            578
# 15    Movie16        4.52            320
# 102  Movie103        4.56            272
# 28    Movie29        4.81            243

# %% [markdown]
# ### Q3 Define the top 5 movies with the least audience.

# %% [markdown]
# #### Logic 1

# %%
data.describe().T["count"].sort_values(ascending = True)[:5].to_frame()
# Out:
#           count
# Movie1      1.0
# Movie71     1.0
# Movie145    1.0
# Movie69     1.0
# Movie68     1.0

# %% [markdown]
# #### Logic 2

# %%
data_logic2.sort_values(by=['NoOfUserRating']).head()
# Out:
#       MovieId MovieRating NoOfUserRating
# 0      Movie1           5              1
# 70    Movie71           4              1
# 144  Movie145           5              1
# 68    Movie69           1              1
# 67    Movie68           5              1

# %% [markdown]
# ### Recommendation Model:
#
# Some of the movies hadn’t been watched and therefore, are not rated by the users. Netflix would like to take this as an opportunity and build a machine learning recommendation algorithm which provides the ratings for each of the users.
#
# - Divide the data into training and test data
# - Build a recommendation model on training data
# - Make predictions on the test data

# %% [markdown]
# ### Logic 1 using Surprise Python Scikit Building and Analyzing Recommender Systems

# %%
# pip install surprise
# or
# conda install -c conda-forge scikit-surprise 
# conda install -c conda-forge/label/gcc7 scikit-surprise 
# conda install -c conda-forge/label/cf201901 scikit-surprise

# %%
from surprise import Reader, accuracy, Dataset
from surprise.model_selection import train_test_split

# %%
data.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 207 columns]

# %%
#now we can use the melt function to setup the data

melt_data = data.melt(id_vars = data.columns[0], value_vars= data.columns[1:], var_name="Movie", value_name="Rating")

melt_data.head()
# Out:
#           user_id   Movie  Rating
# 0  A3R5OBKS7OM2IR  Movie1     5.0
# 1   AH3QC2PC1VTGP  Movie1     NaN
# 2  A3LKP6WPMP9UKX  Movie1     NaN
# 3   AVIY68KEPQ5ZD  Movie1     NaN
# 4  A1CV1WROP5KTTW  Movie1     NaN

# %%
data.describe().T.head()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# Movie1    1.0  5.000000       NaN  5.0  5.0  5.0  5.0  5.0
# Movie2    1.0  5.000000       NaN  5.0  5.0  5.0  5.0  5.0
# Movie3    1.0  2.000000       NaN  2.0  2.0  2.0  2.0  2.0
# Movie4    2.0  5.000000  0.000000  5.0  5.0  5.0  5.0  5.0
# Movie5   29.0  4.103448  1.496301  1.0  4.0  5.0  5.0  5.0

# %%
# set up the rating scale as per the description

ratingReader = Reader(rating_scale=(-1,10))

final_data = Dataset.load_from_df(melt_data.fillna(0), reader=ratingReader)

final_data

# %% [markdown]
# #### Q1 set up the train and test dataset, we have setup the test size 0.50

# %%
trainset, testset = train_test_split(final_data, test_size=0.50)

# %%
# we can use the SVD prediction algo
from surprise import SVD, evaluate

# %% [markdown]
# #### Q2 Build a recommendation model on training data

# %%
# set the SVD predication Algo
algo = SVD()

#The evaluate() method is deprecated. Please use model_selection.cross_validate() instead. 'model_selection.cross_validate() instead.', UserWarning)
# evaluate(algo, data, measures=['RMSE', 'MAE'])

# %%
# fit the trainSet
algo.fit(trainset)

# %%
# test the algo
predictions = algo.test(testset)
predictions
# Out:
# [Prediction(uid='APUVMJA6Q7YZP', iid='Movie141', r_ui=0.0, est=6.406689150573186e-05, details={'was_impossible': False}),
#  Prediction(uid='A16OYIYZF2NJOD', iid='Movie86', r_ui=0.0, est=0.03919292519636697, details={'was_impossible': False}),
#  Prediction(uid='A2E005KLWD9UH9', iid='Movie181', r_ui=0.0, est=-0.009996840086593961, details={'was_impossible': False}),
#  Prediction(uid='A39GW5CBWTIWAZ', iid='Movie180', r_ui=0.0, est=-0.006006175233154609, details={'was_impossible': False}),
#  Prediction(uid='AVE5QEPT0V834', iid='Movie13', r_ui=0.0, est=-0.00819057765217801, details={'was_impossible': False}),
#  Prediction(uid='A28D1YJ1NY60CI', iid='Movie76', r_ui=0.0, est=-0.0014597903516959665, details={'was_impossible': False}),
#  Prediction(uid='A24SQMM6M0QBK2', iid='Movie186', r_ui=0.0, est=0.005058041313156458, details={'was_impossible': False}),
#  Prediction(uid='A3R2I2OVAJ5MAC', iid='Movie40', r_ui=0.0, est=-0.0008012909662862278, details={'was_impossible': False}),
#  Prediction(uid='AIZN7WYHINEFT', iid='Movie61', r_ui=0.0, est=-0.007837826991430763, details={'was_impossible': False}),
#  Prediction(uid='AK3CSMHJKC451', iid='Movie39', r_ui=0.0, est=0.00793768626812641, details={'was_impossible': False}),
#  Prediction(uid='A3PHHTXVI7KKRI', iid='Movie106', r_ui=0.0, est=0.0007334912657577242, details={'was_impossible': False}),
#  Prediction(uid='AOU098G1PQ5E3', iid='Movie21', r_ui=0.0, est=-0.020465110412675624, details={'was_impossible': False}),
#  Prediction(uid='A17LSEN4UY4XZQ', iid='Movie24', r_ui=0.0, est=0.0008201388675006527, details={'was_impossible': False}),
#  Prediction(uid='AOZHXF3JANANV', iid='Movie164', r_ui=0.0, est=-0.0019788594899201595, details={'was_impossible': False}),
#  Prediction(uid='A1UBEXXFF48UBT', iid='Movie38', r_ui=0.0, est=0.0037222203340667726, details={'was_impossible': False}),
#  Prediction(uid='A2X882784291JE', iid='Movie176', r_ui=0.0, est=-0.013081862945079736, details={'was_impossible': False}),
#  Prediction(uid='A3PHVQMJR57DFY', iid='Movie112', r_ui=0.0, est=-0.004958992454517475, details={'was_impossible': False}),
#  Prediction(uid='A30SVQU9SNR65I', iid='Movie124', r_ui=0.0, est=0.010639069719968308, details={'was_impossible': False}),
#  Prediction(uid='A1RRN0ZQHH3AVH', iid='Movie93', r_ui=0.0, est=0.036638352680979036, details={'was_impossible': False}),
#  Prediction(uid='A1GV8XC7RJ5HNE', iid='Movie15', r_ui=0.0, est=0.010460584261438033, details={'was_impossible': False}),
#  Prediction(uid='AJ04L84OLNFAF', iid='Movie161', r_ui=0.0, est=0.057048660862862643, details={'was_impossible': False}),
#  Prediction(uid='A1L8WW6EXH39VF', iid='Movie195', r_ui=0.0, est=0.004777473460309434, details={'was_impossible': False}),
#  Prediction(uid='A3EE0H0NWQ9QVL', iid='Movie115', r_ui=0.0, est=0.00227676671068755, details={'was_impossible': False}),
#  Prediction(uid='A3N4JYOU0QDYZO', iid='Movie5', r_ui=0.0, est=0.04137924484599287, details={'was_impossible': False}),
#  Prediction(uid='A1NGEEU1NPHGY0', iid='Movie50', r_ui=0.0, est=0.0007551890222474711, details={'was_impossible': False}),
#  Prediction(uid='A2O35SG93WHZO2', iid='Movie202', r_ui=0.0, est=0.02951300573263005, details={'was_impossible': False}),
#  Prediction(uid='A2YM3Z6VSVWHIR', iid='Movie149', r_ui=0.0, est=0.002574184360292442, details={'was_impossible': False}),
#  Prediction(uid='A114WO9CT1HK4O', iid='Movie7', r_ui=0.0, est=-0.010632886242285977, details={'was_impossible': False}),
#  Prediction(uid='AVS1T94VSZGWY', iid='Movie110', r_ui=0.0, est=0.0036130092091659627, details={'was_impossible': False}),
#  Prediction(uid='A2RD4FIO2U02OY', iid='Movie139', r_ui=0.0, est=0.00010710292729365634, details={'was_impossible': False}),
#  Prediction(uid='A172UZKI33ZC1E', iid='Movie48', r_ui=0.0, est=0.0017733686187972886, details={'was_impossible': False}),
#  Prediction(uid='A3J2M0DV0WZ0JY', iid='Movie104', r_ui=0.0, est=0.01486450490701463, details={'was_impossible': False}),
#  Prediction(uid='A3RWLUG09DSNPC', iid='Movie113', r_ui=0.0, est=0.013020749372289586, details={'was_impossible': False}),
#  Prediction(uid='A2IN186Z40BRMK', iid='Movie146', r_ui=0.0, est=0.0025796869886662854, details={'was_impossible': False}),
#  Prediction(uid='A2CTYN53JMS0YH', iid='Movie206', r_ui=0.0, est=-0.017090007462377432, details={'was_impossible': False}),
#  Prediction(uid='A2G5SNWDL61VJ7', iid='Movie125', r_ui=0.0, est=0.02199691195482778, details={'was_impossible': False}),
#  Prediction(uid='A38TBQ9UAG72ID', iid='Movie125', r_ui=0.0, est=-0.008557146873152455, details={'was_impossible': False}),
#  Prediction(uid='ASI7VPHDF9PTA', iid='Movie199', r_ui=0.0, est=-0.019105369644478953, details={'was_impossible': False}),
#  Prediction(uid='A18Z6PU746PM8Z', iid='Movie193', r_ui=0.0, est=-0.0068380576736641885, details={'was_impossible': False}),
#  Prediction(uid='A1YUF9YV3084YX', iid='Movie167', r_ui=0.0, est=-0.006991277384689187, details={'was_impossible': False}),
#  Prediction(uid='A1K5L06XRGN51E', iid='Movie183', r_ui=0.0, est=-0.014028281912918938, details={'was_impossible': False}),
#  Prediction(uid='A36A7R5KYQL3CQ', iid='Movie56', r_ui=0.0, est=0.0026750453776078764, details={'was_impossible': False}),
#  Prediction(uid='A2F3N8D5FWSPWT', iid='Movie111', r_ui=0.0, est=0.06427626468896497, details={'was_impossible': False}),
#  Prediction(uid='A1Z3MYPAQYATEC', iid='Movie202', r_ui=0.0, est=0.017674919722546534, details={'was_impossible': False}),
#  Prediction(uid='A1JIPFV4OL520T', iid='Movie48', r_ui=0.0, est=0.0037020108894050274, details={'was_impossible': False}),
#  Prediction(uid='A16OKS0HN6SL4S', iid='Movie169', r_ui=0.0, est=-0.006541826815078533, details={'was_impossible': False}),
#  Prediction(uid='AAM67Y93KTIOL', iid='Movie181', r_ui=0.0, est=0.005803773133595147, details={'was_impossible': False}),
#  Prediction(uid='AT86RADY54FAO', iid='Movie5', r_ui=0.0, est=0.004015990009018644, details={'was_impossible': False}),
#  Prediction(uid='A1DG5LL4FPR45R', iid='Movie68', r_ui=0.0, est=0.006709411969091139, details={'was_impossible': False}),
#  Prediction(uid='A5V62IILGANFN', iid='Movie125', r_ui=0.0, est=0.011020157198065483, details={'was_impossible': False}),
#  Prediction(uid='A1QYU815OBKZSR', iid='Movie27', r_ui=0.0, est=0.018857083321881962, details={'was_impossible': False}),
#  Prediction(uid='A1T4OVTKTUQTJC', iid='Movie196', r_ui=0.0, est=0.03789305964255618, details={'was_impossible': False}),
#  Prediction(uid='A1DXG16KE9959Y', iid='Movie36', r_ui=0.0, est=-0.020871256783659753, details={'was_impossible': False}),
#  Prediction(uid='A160O9M3UPJ8NE', iid='Movie103', r_ui=0.0, est=0.45330301515973703, details={'was_impossible': False}),
#  Prediction(uid='A3AW8XP45YVIIZ', iid='Movie21', r_ui=0.0, est=0.006273346275093239, details={'was_impossible': False}),
#  Prediction(uid='A230YY5H0BJ2Y7', iid='Movie43', r_ui=0.0, est=0.04305474058057701, details={'was_impossible': False}),
#  Prediction(uid='A30NY9L37OCQ3', iid='Movie4', r_ui=0.0, est=0.006167005097236, details={'was_impossible': False}),
#  Prediction(uid='AAH27NBZ0OLEF', iid='Movie140', r_ui=0.0, est=-0.07741123473477662, details={'was_impossible': False}),
#  Prediction(uid='A33TQO18Q5S922', iid='Movie182', r_ui=0.0, est=0.009791774459857905, details={'was_impossible': False}),
#  Prediction(uid='AJCM9IDJ1PZZ5', iid='Movie23', r_ui=0.0, est=0.002300328435855814, details={'was_impossible': False}),
#  Prediction(uid='A2X0QQ0V39SZKH', iid='Movie47', r_ui=0.0, est=0.006809903609433121, details={'was_impossible': False}),
#  Prediction(uid='A1BLCLTWOR1DFP', iid='Movie163', r_ui=0.0, est=-0.015816869807224743, details={'was_impossible': False}),
#  Prediction(uid='A36JK8MZ59X3BH', iid='Movie72', r_ui=0.0, est=0.00380162889966007, details={'was_impossible': False}),
#  Prediction(uid='A3G9F5EGOJFWPB', iid='Movie31', r_ui=0.0, est=0.0005501259859790331, details={'was_impossible': False}),
#  Prediction(uid='A3J7XF93IKBLA5', iid='Movie45', r_ui=0.0, est=0.008173716054385771, details={'was_impossible': False}),
#  Prediction(uid='A1E8OGV9SO0E0P', iid='Movie132', r_ui=0.0, est=0.02349168603805918, details={'was_impossible': False}),
#  Prediction(uid='A3S98L5B1SR9P1', iid='Movie194', r_ui=0.0, est=0.03819443003043599, details={'was_impossible': False}),
#  Prediction(uid='A1HBK6HV5TS79U', iid='Movie43', r_ui=0.0, est=0.04799444544248299, details={'was_impossible': False}),
#  Prediction(uid='A17Q3TKXPYP5HT', iid='Movie190', r_ui=0.0, est=0.01738081476343778, details={'was_impossible': False}),
#  Prediction(uid='A3FSAHNS96WIV4', iid='Movie35', r_ui=0.0, est=-0.001350735874703357, details={'was_impossible': False}),
#  Prediction(uid='A38JFF6SGZEO37', iid='Movie18', r_ui=0.0, est=0.014430308013429816, details={'was_impossible': False}),
#  Prediction(uid='ANUWEAJ7WGRWB', iid='Movie59', r_ui=0.0, est=-0.0170382721921023, details={'was_impossible': False}),
#  Prediction(uid='A3S7SE6WXNARVR', iid='Movie10', r_ui=0.0, est=0.0052233964042467385, details={'was_impossible': False}),
#  Prediction(uid='A2995C43JA5B29', iid='Movie70', r_ui=0.0, est=0.002838472478997378, details={'was_impossible': False}),
#  Prediction(uid='A1CZPJRF0VWKN0', iid='Movie111', r_ui=0.0, est=0.021937516266176793, details={'was_impossible': False}),
#  Prediction(uid='A3QEMYIM4Z5JPK', iid='Movie152', r_ui=0.0, est=-0.019010160240588547, details={'was_impossible': False}),
#  Prediction(uid='A3UP4AV1A8Y6XH', iid='Movie61', r_ui=0.0, est=0.006410200287116474, details={'was_impossible': False}),
#  Prediction(uid='A2OXDJP1Z3LNOK', iid='Movie100', r_ui=0.0, est=0.0021888512215202383, details={'was_impossible': False}),
#  Prediction(uid='A2JP2NU9YGPV9I', iid='Movie3', r_ui=0.0, est=0.026114639508536985, details={'was_impossible': False}),
#  Prediction(uid='A2PY7WF3OQP3ZH', iid='Movie70', r_ui=0.0, est=0.011624016577736374, details={'was_impossible': False}),
#  Prediction(uid='A26D4LCXTF3PSW', iid='Movie173', r_ui=0.0, est=0.004852588357089349, details={'was_impossible': False}),
#  Prediction(uid='A3SB0HA8HO7AF4', iid='Movie34', r_ui=0.0, est=0.0003688586338368438, details={'was_impossible': False}),
#  Prediction(uid='A347B5PO4URX8A', iid='Movie56', r_ui=0.0, est=-0.007525713076117935, details={'was_impossible': False}),
#  Prediction(uid='A119NDXKRBCB7T', iid='Movie142', r_ui=0.0, est=0.0045584669561558044, details={'was_impossible': False}),
#  Prediction(uid='A326Y8FFWXB1E7', iid='Movie136', r_ui=0.0, est=0.0029856913007764163, details={'was_impossible': False}),
#  Prediction(uid='A2WOPJ88JJN43X', iid='Movie4', r_ui=0.0, est=0.01597372524721896, details={'was_impossible': False}),
#  Prediction(uid='A9S7HNDRRNIXS', iid='Movie132', r_ui=0.0, est=-0.01619667288739257, details={'was_impossible': False}),
#  Prediction(uid='A1QQD8DM42R94F', iid='Movie92', r_ui=0.0, est=0.04097263866077405, details={'was_impossible': False}),
#  Prediction(uid='A2RWFUZF0WWLU0', iid='Movie71', r_ui=0.0, est=0.007243729048277192, details={'was_impossible': False}),
#  Prediction(uid='AA2F97CWV8EU8', iid='Movie138', r_ui=0.0, est=0.030871508116756097, details={'was_impossible': False}),
#  Prediction(uid='A312KM8IVZCEPA', iid='Movie166', r_ui=0.0, est=0.0034438050512841656, details={'was_impossible': False}),
#  Prediction(uid='A1R6KGK8TRJAGV', iid='Movie203', r_ui=0.0, est=0.0015229797729205963, details={'was_impossible': False}),
#  Prediction(uid='A2I4JD2V4IUY4G', iid='Movie54', r_ui=0.0, est=-0.009236367663546297, details={'was_impossible': False}),
#  Prediction(uid='AOR7JA72RVYIN', iid='Movie88', r_ui=0.0, est=0.005150927069435873, details={'was_impossible': False}),
#  Prediction(uid='A2MHJJ4HXN8X40', iid='Movie112', r_ui=0.0, est=-0.017702160953201984, details={'was_impossible': False}),
#  Prediction(uid='A2VBT1E9ZSH8KF', iid='Movie134', r_ui=0.0, est=0.027095404114886534, details={'was_impossible': False}),
#  Prediction(uid='A29WU2UUFP3H5B', iid='Movie105', r_ui=0.0, est=-0.016971663445557672, details={'was_impossible': False}),
#  Prediction(uid='A2X128XN7VIC1P', iid='Movie146', r_ui=0.0, est=0.0018038365971473347, details={'was_impossible': False}),
#  Prediction(uid='AWWV7F7W84B5C', iid='Movie182', r_ui=0.0, est=0.025005095092959895, details={'was_impossible': False}),
#  Prediction(uid='A3ADK3ZTJ87915', iid='Movie196', r_ui=0.0, est=0.014529610780681157, details={'was_impossible': False}),
#  Prediction(uid='A34BWIRIDNHWLG', iid='Movie146', r_ui=0.0, est=0.005258535815966248, details={'was_impossible': False}),
#  Prediction(uid='A2QWA1Z5W7GSFI', iid='Movie77', r_ui=0.0, est=0.003732953569555164, details={'was_impossible': False}),
#  Prediction(uid='A3DRNX6XIM6GRY', iid='Movie80', r_ui=0.0, est=0.018949016173953392, details={'was_impossible': False}),
#  Prediction(uid='A5I8OWSLWM1MF', iid='Movie90', r_ui=0.0, est=-0.013196446717241184, details={'was_impossible': False}),
#  Prediction(uid='A35J4XGRWXVZ00', iid='Movie70', r_ui=0.0, est=-0.006456141590191367, details={'was_impossible': False}),
#  Prediction(uid='A3SXFF9QGG3ZI9', iid='Movie144', r_ui=0.0, est=0.02090863474685145, details={'was_impossible': False}),
#  Prediction(uid='A3K9VLEPZW80JD', iid='Movie136', r_ui=0.0, est=0.0006343916833784213, details={'was_impossible': False}),
#  Prediction(uid='A2OP1HD9RGX5OW', iid='Movie121', r_ui=0.0, est=0.025737594214017445, details={'was_impossible': False}),
#  Prediction(uid='A2PNTEDGMOLMOY', iid='Movie191', r_ui=0.0, est=0.024718795151893236, details={'was_impossible': False}),
#  Prediction(uid='A1D9BIL79OJSZM', iid='Movie73', r_ui=0.0, est=0.001973717246007478, details={'was_impossible': False}),
#  Prediction(uid='A2IM08YXPW1EJH', iid='Movie33', r_ui=0.0, est=-0.015164977265063717, details={'was_impossible': False}),
#  Prediction(uid='A60VSG3P3JE6G', iid='Movie112', r_ui=0.0, est=0.0025238001052181325, details={'was_impossible': False}),
#  Prediction(uid='A28D1YJ1NY60CI', iid='Movie140', r_ui=0.0, est=0.6016630862615537, details={'was_impossible': False}),
#  Prediction(uid='A3I66IXERB9WS3', iid='Movie172', r_ui=0.0, est=0.010470060893220445, details={'was_impossible': False}),
#  Prediction(uid='A3HA6YF8EII0ZV', iid='Movie177', r_ui=0.0, est=-0.0002036754655538875, details={'was_impossible': False}),
#  Prediction(uid='A27FQH5GHWY7Z8', iid='Movie179', r_ui=0.0, est=0.014537451725048278, details={'was_impossible': False}),
#  Prediction(uid='AYCT65TQ1PLL4', iid='Movie127', r_ui=0.0, est=-0.04038159281666909, details={'was_impossible': False}),
#  Prediction(uid='A27KKLPG8T000T', iid='Movie26', r_ui=0.0, est=-0.003341642055670224, details={'was_impossible': False}),
#  Prediction(uid='A2T5AOPGL4E1GB', iid='Movie13', r_ui=0.0, est=-0.003029502083805813, details={'was_impossible': False}),
#  Prediction(uid='A3C1D6OUUQTNLF', iid='Movie108', r_ui=0.0, est=0.12155398835590692, details={'was_impossible': False}),
#  Prediction(uid='A35ZK3M8L9JUPX', iid='Movie37', r_ui=0.0, est=0.03361844936848568, details={'was_impossible': False}),
#  Prediction(uid='A18MPF9GFCYJGF', iid='Movie75', r_ui=0.0, est=-0.014196491796628186, details={'was_impossible': False}),
#  Prediction(uid='AMCHPZID39EDL', iid='Movie53', r_ui=0.0, est=0.006309094232666457, details={'was_impossible': False}),
#  Prediction(uid='A2EXR71POAF4DR', iid='Movie54', r_ui=0.0, est=-0.016810207242749176, details={'was_impossible': False}),
#  Prediction(uid='A3LRVXXVMDNVNM', iid='Movie75', r_ui=0.0, est=0.00015920039010719478, details={'was_impossible': False}),
#  Prediction(uid='A2ST93KYSU1S77', iid='Movie121', r_ui=0.0, est=0.05218985666127818, details={'was_impossible': False}),
#  Prediction(uid='A3P1HYLA6NYFC5', iid='Movie9', r_ui=0.0, est=0.01234753629258023, details={'was_impossible': False}),
#  Prediction(uid='AJI1WYQV21RD7', iid='Movie7', r_ui=0.0, est=0.013506741590891824, details={'was_impossible': False}),
#  Prediction(uid='A1IAFE3I4DL4EK', iid='Movie7', r_ui=0.0, est=-0.006075372904053689, details={'was_impossible': False}),
#  Prediction(uid='A1MRGQHQM41AM4', iid='Movie139', r_ui=0.0, est=-0.0009897060029226967, details={'was_impossible': False}),
#  Prediction(uid='A11PNE41SBMR5X', iid='Movie130', r_ui=0.0, est=-0.004401220132975725, details={'was_impossible': False}),
#  Prediction(uid='A3JQW0OE85SL0R', iid='Movie164', r_ui=0.0, est=-0.011685636779550146, details={'was_impossible': False}),
#  Prediction(uid='A2WJO3HNUTT8F8', iid='Movie129', r_ui=0.0, est=0.00680243678500192, details={'was_impossible': False}),
#  Prediction(uid='AF18LCM3NQQG6', iid='Movie116', r_ui=0.0, est=-0.00014614070644580757, details={'was_impossible': False}),
#  Prediction(uid='A22M5YNN8NA5Z7', iid='Movie40', r_ui=0.0, est=0.002413715104821801, details={'was_impossible': False}),
#  Prediction(uid='A22FQXLHCWZIXI', iid='Movie51', r_ui=0.0, est=-0.0036742519964159115, details={'was_impossible': False}),
#  Prediction(uid='A36311XF4O81IK', iid='Movie133', r_ui=0.0, est=0.02168854299410361, details={'was_impossible': False}),
#  Prediction(uid='A3A6ZHKZ8SKV1U', iid='Movie67', r_ui=0.0, est=-0.00041176393348019147, details={'was_impossible': False}),
#  Prediction(uid='A303RM5J75FRPF', iid='Movie43', r_ui=0.0, est=0.010421553382640614, details={'was_impossible': False}),
#  Prediction(uid='AJ561ELTCUY6P', iid='Movie109', r_ui=0.0, est=-0.0012787425464304558, details={'was_impossible': False}),
#  Prediction(uid='A31YQQYX9PU04Z', iid='Movie167', r_ui=0.0, est=0.011251121620554194, details={'was_impossible': False}),
#  Prediction(uid='A1YUOGDE7FAWGM', iid='Movie123', r_ui=0.0, est=0.0034939065732926267, details={'was_impossible': False}),
#  Prediction(uid='A21DCJZXG0LHK2', iid='Movie105', r_ui=0.0, est=0.0018930209760559258, details={'was_impossible': False}),
#  Prediction(uid='A34AK2G3DMQ6T3', iid='Movie49', r_ui=0.0, est=-0.0030805961100255352, details={'was_impossible': False}),
#  Prediction(uid='AB1OA9RKZZD62', iid='Movie49', r_ui=0.0, est=0.004595291076746388, details={'was_impossible': False}),
#  Prediction(uid='A2IZHS56N6FRHK', iid='Movie72', r_ui=0.0, est=0.005078496591942372, details={'was_impossible': False}),
#  Prediction(uid='A2N5CU5M5UUMU1', iid='Movie32', r_ui=0.0, est=0.0025169439012540096, details={'was_impossible': False}),
#  Prediction(uid='A3HJLWX3FV2MCF', iid='Movie37', r_ui=0.0, est=0.020477959397630308, details={'was_impossible': False}),
#  Prediction(uid='A1JC0STX1TKDU', iid='Movie151', r_ui=0.0, est=0.004271581814714764, details={'was_impossible': False}),
#  Prediction(uid='A1MLZ54BHIR95L', iid='Movie79', r_ui=0.0, est=-0.004604613694738191, details={'was_impossible': False}),
#  Prediction(uid='AG4O115UCHPM9', iid='Movie50', r_ui=0.0, est=-0.018309426410321628, details={'was_impossible': False}),
#  Prediction(uid='A1U5GBB6VX9FEL', iid='Movie69', r_ui=0.0, est=-0.018295807198645653, details={'was_impossible': False}),
#  Prediction(uid='A3QLS4TB7SDICW', iid='Movie124', r_ui=0.0, est=-0.01780282603683392, details={'was_impossible': False}),
#  Prediction(uid='AFFK11HUGFK75', iid='Movie142', r_ui=0.0, est=-0.0018016571080547994, details={'was_impossible': False}),
#  Prediction(uid='A1L5BP9OVTIPW2', iid='Movie19', r_ui=0.0, est=-0.011477402971240558, details={'was_impossible': False}),
#  Prediction(uid='A8O6G4N0AVBO', iid='Movie171', r_ui=0.0, est=0.020913716826032935, details={'was_impossible': False}),
#  Prediction(uid='A3RTQ5MKHXKPLK', iid='Movie181', r_ui=0.0, est=0.005112977697530496, details={'was_impossible': False}),
#  Prediction(uid='A3KXIJ17A3JROF', iid='Movie175', r_ui=0.0, est=0.006037976536242162, details={'was_impossible': False}),
#  Prediction(uid='AAECAHBNP1VD2', iid='Movie66', r_ui=0.0, est=-0.007400016636099904, details={'was_impossible': False}),
#  Prediction(uid='A1BXVZSQOJE6UE', iid='Movie33', r_ui=0.0, est=0.0007649639150635323, details={'was_impossible': False}),
#  Prediction(uid='A26NRTM9VWR94O', iid='Movie116', r_ui=0.0, est=-0.002831715942328783, details={'was_impossible': False}),
#  Prediction(uid='A1RE9GXFQGK15', iid='Movie149', r_ui=0.0, est=-0.015952898043656738, details={'was_impossible': False}),
#  Prediction(uid='A18RQ2URRGIIEA', iid='Movie14', r_ui=0.0, est=0.0011703088336822987, details={'was_impossible': False}),
#  Prediction(uid='A21MMP6GHWDC1E', iid='Movie105', r_ui=0.0, est=-0.005393508385485468, details={'was_impossible': False}),
#  Prediction(uid='AE39CXFP4UNN5', iid='Movie58', r_ui=0.0, est=0.003958718887498769, details={'was_impossible': False}),
#  Prediction(uid='AIIR8E34EDKCQ', iid='Movie122', r_ui=0.0, est=0.001252984119029854, details={'was_impossible': False}),
#  Prediction(uid='A1QYU815OBKZSR', iid='Movie24', r_ui=0.0, est=0.017146262195872897, details={'was_impossible': False}),
#  Prediction(uid='A4LNTR1DZQXHC', iid='Movie23', r_ui=0.0, est=0.025395476581934417, details={'was_impossible': False}),
#  Prediction(uid='A20YOE9PO3DETE', iid='Movie122', r_ui=0.0, est=0.005649407316058674, details={'was_impossible': False}),
#  Prediction(uid='AR4O6ZVN45NJM', iid='Movie32', r_ui=0.0, est=0.0005154726798166642, details={'was_impossible': False}),
#  Prediction(uid='A2LD0YL2U1P058', iid='Movie161', r_ui=0.0, est=0.04588665990028051, details={'was_impossible': False}),
#  Prediction(uid='A28DLAVPZXLH7A', iid='Movie19', r_ui=0.0, est=-0.0075428238708523665, details={'was_impossible': False}),
#  Prediction(uid='A1BXVZSQOJE6UE', iid='Movie106', r_ui=0.0, est=-0.001137542936193725, details={'was_impossible': False}),
#  Prediction(uid='A1RFC9QRL3FURE', iid='Movie74', r_ui=0.0, est=-0.019696183042201332, details={'was_impossible': False}),
#  Prediction(uid='A14J77AYM5WE0O', iid='Movie190', r_ui=0.0, est=0.02277242654964251, details={'was_impossible': False}),
#  Prediction(uid='ATPRC7Q7YSRT0', iid='Movie143', r_ui=0.0, est=0.003984769689642231, details={'was_impossible': False}),
#  Prediction(uid='A26Q6QE0J3L0VX', iid='Movie60', r_ui=0.0, est=-0.022044242404346548, details={'was_impossible': False}),
#  Prediction(uid='A3SXFF9QGG3ZI9', iid='Movie150', r_ui=0.0, est=0.016664239581216655, details={'was_impossible': False}),
#  Prediction(uid='A2XNJBU7AFNT61', iid='Movie34', r_ui=0.0, est=-0.012324186773855716, details={'was_impossible': False}),
#  Prediction(uid='A2TIO1SVM1J3KJ', iid='Movie11', r_ui=0.0, est=0.007510177237935789, details={'was_impossible': False}),
#  Prediction(uid='A17UAYGNHJ5QJL', iid='Movie113', r_ui=0.0, est=-0.00012581975252001776, details={'was_impossible': False}),
#  Prediction(uid='A2ELP13J2HSGJQ', iid='Movie94', r_ui=0.0, est=-0.0029452582816180684, details={'was_impossible': False}),
#  Prediction(uid='AFWYZRQK3MVQL', iid='Movie48', r_ui=0.0, est=0.0023274569209479345, details={'was_impossible': False}),
#  Prediction(uid='A3GKNZLIZ3IH7H', iid='Movie77', r_ui=0.0, est=0.010784362465930286, details={'was_impossible': False}),
#  Prediction(uid='A11KRMIA0ES88I', iid='Movie121', r_ui=0.0, est=0.023479918596053473, details={'was_impossible': False}),
#  Prediction(uid='A23CSKREGK1SOS', iid='Movie205', r_ui=0.0, est=-0.009029090121815075, details={'was_impossible': False}),
#  Prediction(uid='AF0HOX2YGDIUT', iid='Movie195', r_ui=0.0, est=-0.0026962734630460172, details={'was_impossible': False}),
#  Prediction(uid='AZMXYTMWZ26RQ', iid='Movie196', r_ui=0.0, est=0.022615764863690213, details={'was_impossible': False}),
#  Prediction(uid='A2LFQ7A7F67934', iid='Movie180', r_ui=0.0, est=-0.006957730637276116, details={'was_impossible': False}),
#  Prediction(uid='A1JN58PTDXXT63', iid='Movie170', r_ui=0.0, est=0.05917616794977354, details={'was_impossible': False}),
#  Prediction(uid='AZNADO488RR7H', iid='Movie170', r_ui=0.0, est=0.0034229151337648034, details={'was_impossible': False}),
#  Prediction(uid='A1A3UCSCBIJZ46', iid='Movie54', r_ui=0.0, est=0.00945223264437356, details={'was_impossible': False}),
#  Prediction(uid='AH4XRJL95TK6E', iid='Movie144', r_ui=0.0, est=0.0027912722019030056, details={'was_impossible': False}),
#  Prediction(uid='ATKL8C5IQ56E9', iid='Movie178', r_ui=0.0, est=0.02029088349144148, details={'was_impossible': False}),
#  Prediction(uid='A1961Z4LQ7SOJF', iid='Movie102', r_ui=0.0, est=-0.01261941540346534, details={'was_impossible': False}),
#  Prediction(uid='ABMM1URE5LJD4', iid='Movie134', r_ui=0.0, est=0.02092126714370801, details={'was_impossible': False}),
#  Prediction(uid='A3A5LGW1JF0RR5', iid='Movie206', r_ui=0.0, est=0.015648219273841413, details={'was_impossible': False}),
#  Prediction(uid='A39Q8K6XZDDEPR', iid='Movie13', r_ui=0.0, est=0.0054159556487052285, details={'was_impossible': False}),
#  Prediction(uid='A33Q0WEEUQ32TX', iid='Movie172', r_ui=0.0, est=0.01627719792348259, details={'was_impossible': False}),
#  Prediction(uid='A2U1M5DOGULIQA', iid='Movie63', r_ui=0.0, est=0.004581233516482541, details={'was_impossible': False}),
#  Prediction(uid='A5F9KZVO8KFHG', iid='Movie156', r_ui=0.0, est=0.001237603127038689, details={'was_impossible': False}),
#  Prediction(uid='A1RE9GXFQGK15', iid='Movie81', r_ui=0.0, est=0.01142546531502342, details={'was_impossible': False}),
#  Prediction(uid='A1P2F8841W7LRU', iid='Movie95', r_ui=0.0, est=0.014762569441777895, details={'was_impossible': False}),
#  Prediction(uid='A3Q04XXGGED746', iid='Movie44', r_ui=0.0, est=0.03204896618376463, details={'was_impossible': False}),
#  Prediction(uid='A2KO0Q230MSA78', iid='Movie28', r_ui=0.0, est=-0.006688612646169156, details={'was_impossible': False}),
#  Prediction(uid='ATBUQP91WNKJU', iid='Movie115', r_ui=0.0, est=-0.005112543609341547, details={'was_impossible': False}),
#  Prediction(uid='AEHQB78GFKSVU', iid='Movie49', r_ui=0.0, est=0.04673972305542673, details={'was_impossible': False}),
#  Prediction(uid='A1FW6TKOEBVVMK', iid='Movie131', r_ui=0.0, est=-0.003167687920103912, details={'was_impossible': False}),
#  Prediction(uid='A2D0PI4CACTE7I', iid='Movie195', r_ui=0.0, est=0.013722816263632254, details={'was_impossible': False}),
#  Prediction(uid='A3TCVBS8C75NUG', iid='Movie8', r_ui=0.0, est=-0.002722545571758994, details={'was_impossible': False}),
#  Prediction(uid='A2KC758GRIEEK4', iid='Movie193', r_ui=0.0, est=0.0032400760924597982, details={'was_impossible': False}),
#  Prediction(uid='A3MJBLF5C0FCWV', iid='Movie74', r_ui=0.0, est=-0.013282917482165146, details={'was_impossible': False}),
#  Prediction(uid='A3HXHW3QXM5FMP', iid='Movie40', r_ui=0.0, est=-0.004323949964641471, details={'was_impossible': False}),
#  Prediction(uid='AR4O6ZVN45NJM', iid='Movie37', r_ui=0.0, est=0.006584508041271864, details={'was_impossible': False}),
#  Prediction(uid='A4G4HE8KQ0R7X', iid='Movie18', r_ui=0.0, est=0.005873633456885852, details={'was_impossible': False}),
#  Prediction(uid='A2IHWLJKHBABTR', iid='Movie37', r_ui=0.0, est=-0.0032601943496930463, details={'was_impossible': False}),
#  Prediction(uid='A9HSEUVAO6UMV', iid='Movie60', r_ui=0.0, est=0.0006618681193732989, details={'was_impossible': False}),
#  Prediction(uid='A22J3OCEN0J191', iid='Movie181', r_ui=0.0, est=0.010536513527018343, details={'was_impossible': False}),
#  Prediction(uid='A2C67F0TPHMI7D', iid='Movie73', r_ui=0.0, est=0.014374150444285139, details={'was_impossible': False}),
#  Prediction(uid='A1VIMSCVF8KC0D', iid='Movie129', r_ui=0.0, est=0.0019078835194710209, details={'was_impossible': False}),
#  Prediction(uid='A3S98L5B1SR9P1', iid='Movie176', r_ui=0.0, est=0.003416455167909671, details={'was_impossible': False}),
#  Prediction(uid='A3KXIJ17A3JROF', iid='Movie141', r_ui=0.0, est=0.014239109772324454, details={'was_impossible': False}),
#  Prediction(uid='ATSYIL9MUJPY7', iid='Movie3', r_ui=0.0, est=-0.01945938354115251, details={'was_impossible': False}),
#  Prediction(uid='A3EE8OSA9LIT7Y', iid='Movie32', r_ui=0.0, est=0.032360753247451246, details={'was_impossible': False}),
#  Prediction(uid='A2IS1BTDQ6MGX', iid='Movie194', r_ui=0.0, est=0.049442833524023566, details={'was_impossible': False}),
#  Prediction(uid='A15G80TVI5M8IR', iid='Movie111', r_ui=0.0, est=0.046043067085896006, details={'was_impossible': False}),
#  Prediction(uid='A1HT6J8CJNCHHM', iid='Movie148', r_ui=0.0, est=0.008760542932100712, details={'was_impossible': False}),
#  Prediction(uid='A1M1TLF25RQU3E', iid='Movie114', r_ui=0.0, est=-0.008075167824174612, details={'was_impossible': False}),
#  Prediction(uid='A2VOSP5P677T6P', iid='Movie94', r_ui=0.0, est=0.004376783861979039, details={'was_impossible': False}),
#  Prediction(uid='A3M0YG3GYEYW7Z', iid='Movie156', r_ui=0.0, est=0.021370315433032694, details={'was_impossible': False}),
#  Prediction(uid='A354ZK2KDRVKW8', iid='Movie161', r_ui=0.0, est=0.03129513747348778, details={'was_impossible': False}),
#  Prediction(uid='ADUD2B1M768W2', iid='Movie115', r_ui=0.0, est=-0.016033254685819953, details={'was_impossible': False}),
#  Prediction(uid='A3HZ47QXB63B26', iid='Movie123', r_ui=0.0, est=-0.015784751159693133, details={'was_impossible': False}),
#  Prediction(uid='AQO5CAUW83IXR', iid='Movie163', r_ui=0.0, est=0.003302269114664025, details={'was_impossible': False}),
#  Prediction(uid='A3I37BOCIZSMMK', iid='Movie93', r_ui=0.0, est=0.04185128323461251, details={'was_impossible': False}),
#  Prediction(uid='A2PV6GK1HV54Y9', iid='Movie191', r_ui=0.0, est=0.01331053651547931, details={'was_impossible': False}),
#  Prediction(uid='A2Y7BSQG9V3LNG', iid='Movie50', r_ui=0.0, est=-0.0033754234176190945, details={'was_impossible': False}),
#  Prediction(uid='A2ELP13J2HSGJQ', iid='Movie166', r_ui=0.0, est=-0.005451867581377279, details={'was_impossible': False}),
#  Prediction(uid='A34JCDB3DPJ1I5', iid='Movie20', r_ui=0.0, est=0.0019731894378636206, details={'was_impossible': False}),
#  Prediction(uid='A12GC85NZMRMI', iid='Movie75', r_ui=0.0, est=0.012639274086665875, details={'was_impossible': False}),
#  Prediction(uid='A17BU4HWOJTY10', iid='Movie28', r_ui=0.0, est=-0.013864095019112677, details={'was_impossible': False}),
#  Prediction(uid='A38JC53FS08ETC', iid='Movie180', r_ui=0.0, est=0.0018366544949532937, details={'was_impossible': False}),
#  Prediction(uid='A2EQ2ARCU102TM', iid='Movie107', r_ui=0.0, est=-0.037284626727794645, details={'was_impossible': False}),
#  Prediction(uid='A108W48BGLSBHW', iid='Movie15', r_ui=0.0, est=0.011842257941652612, details={'was_impossible': False}),
#  Prediction(uid='A38CTEEF4ZNKGW', iid='Movie86', r_ui=0.0, est=-0.007538252498323406, details={'was_impossible': False}),
#  Prediction(uid='A2GPEV42IO41CI', iid='Movie87', r_ui=0.0, est=-0.000781966254293387, details={'was_impossible': False}),
#  Prediction(uid='AHYN0IRP5MB57', iid='Movie199', r_ui=0.0, est=0.038199482891099645, details={'was_impossible': False}),
#  Prediction(uid='AC69BSFLSG0MR', iid='Movie164', r_ui=0.0, est=0.017730089519754966, details={'was_impossible': False}),
#  Prediction(uid='A1YR4OM2QLQ1LY', iid='Movie131', r_ui=0.0, est=0.0067198931200089795, details={'was_impossible': False}),
#  Prediction(uid='A1OBM38R2NOIR7', iid='Movie51', r_ui=0.0, est=0.001148812041563918, details={'was_impossible': False}),
#  Prediction(uid='A1BMKEJ61X57EU', iid='Movie59', r_ui=0.0, est=-0.0009230821888466245, details={'was_impossible': False}),
#  Prediction(uid='A1PVE07QRSZ8CA', iid='Movie163', r_ui=0.0, est=0.006798873219817203, details={'was_impossible': False}),
#  Prediction(uid='A18CRS4FLVH5YW', iid='Movie81', r_ui=0.0, est=-0.0069301572826234725, details={'was_impossible': False}),
#  Prediction(uid='A2ADTTN16H3MJ7', iid='Movie195', r_ui=0.0, est=-0.012099598701814207, details={'was_impossible': False}),
#  Prediction(uid='A3U3IT3S2GW8L1', iid='Movie145', r_ui=0.0, est=-0.003044935518224934, details={'was_impossible': False}),
#  Prediction(uid='A31EO8K3W0LH0B', iid='Movie43', r_ui=0.0, est=0.03487439315661378, details={'was_impossible': False}),
#  Prediction(uid='A16OYIYZF2NJOD', iid='Movie155', r_ui=0.0, est=0.012129236154042378, details={'was_impossible': False}),
#  Prediction(uid='A2PY7WF3OQP3ZH', iid='Movie81', r_ui=0.0, est=0.010072946528847382, details={'was_impossible': False}),
#  Prediction(uid='A1EF6EKYSQO7FM', iid='Movie193', r_ui=0.0, est=-0.0022573107086047983, details={'was_impossible': False}),
#  Prediction(uid='A3HWBITYEYQNGS', iid='Movie18', r_ui=0.0, est=0.017527422164184348, details={'was_impossible': False}),
#  Prediction(uid='A1CA4IP0DCPF7W', iid='Movie33', r_ui=0.0, est=-0.01604687649996195, details={'was_impossible': False}),
#  Prediction(uid='A2A5PZIN174BEG', iid='Movie28', r_ui=0.0, est=0.00590631762837468, details={'was_impossible': False}),
#  Prediction(uid='A3BZGG7GZWD5IE', iid='Movie84', r_ui=0.0, est=0.007446440284608613, details={'was_impossible': False}),
#  Prediction(uid='A1XHBAW7FXGCJO', iid='Movie187', r_ui=0.0, est=-0.0007438292926806866, details={'was_impossible': False}),
#  Prediction(uid='AJNQB9SYJ418N', iid='Movie56', r_ui=0.0, est=0.001771827344655641, details={'was_impossible': False}),
#  Prediction(uid='A26ZSYRPA1TCI5', iid='Movie62', r_ui=0.0, est=0.0021468133901310082, details={'was_impossible': False}),
#  Prediction(uid='A1UEWW6J65A245', iid='Movie173', r_ui=0.0, est=0.016193914257986552, details={'was_impossible': False}),
#  Prediction(uid='AVF6AOZ0XDRAG', iid='Movie120', r_ui=0.0, est=0.007578340557970353, details={'was_impossible': False}),
#  Prediction(uid='A2IDX2U03CL90F', iid='Movie98', r_ui=0.0, est=0.010644052839683393, details={'was_impossible': False}),
#  Prediction(uid='AHNR50AY2C6AZ', iid='Movie161', r_ui=0.0, est=0.07315589424062008, details={'was_impossible': False}),
#  Prediction(uid='A1LY0TCN8ICY60', iid='Movie196', r_ui=0.0, est=0.01332088787832797, details={'was_impossible': False}),
#  Prediction(uid='A2CVD8DLA9BXVZ', iid='Movie100', r_ui=0.0, est=-0.0160958395543509, details={'was_impossible': False}),
#  Prediction(uid='A1LW1I7GA03J74', iid='Movie46', r_ui=0.0, est=0.009642602098626885, details={'was_impossible': False}),
#  Prediction(uid='A1HGUIQGU1G1PE', iid='Movie22', r_ui=0.0, est=0.014865700499816281, details={'was_impossible': False}),
#  Prediction(uid='A2WSWL714Q0N1W', iid='Movie180', r_ui=0.0, est=-0.009176871395248476, details={'was_impossible': False}),
#  Prediction(uid='A2S7LMWUXK3NN7', iid='Movie11', r_ui=0.0, est=0.0011648457624442443, details={'was_impossible': False}),
#  Prediction(uid='A3UORV8A9D5L2E', iid='Movie44', r_ui=0.0, est=-0.0022691248443504897, details={'was_impossible': False}),
#  Prediction(uid='AQ8DU6XVA3USJ', iid='Movie36', r_ui=0.0, est=0.0011272984537300523, details={'was_impossible': False}),
#  Prediction(uid='A19A0YVRQX8B1L', iid='Movie40', r_ui=0.0, est=-0.0076012767387236835, details={'was_impossible': False}),
#  Prediction(uid='A39U5WXH2I4A5S', iid='Movie142', r_ui=0.0, est=-0.00478381771984715, details={'was_impossible': False}),
#  Prediction(uid='ATSYIL9MUJPY7', iid='Movie49', r_ui=0.0, est=-0.012432273776663783, details={'was_impossible': False}),
#  Prediction(uid='A22B0V6LQPHZ6Q', iid='Movie134', r_ui=0.0, est=0.01454469397565239, details={'was_impossible': False}),
#  Prediction(uid='AALRWQX4EOYHM', iid='Movie155', r_ui=0.0, est=-0.011006018290482977, details={'was_impossible': False}),
#  Prediction(uid='APORF8UOGHSXJ', iid='Movie15', r_ui=0.0, est=0.002024554388830868, details={'was_impossible': False}),
#  Prediction(uid='A2ZFAYA9NKP2SA', iid='Movie90', r_ui=0.0, est=0.004595376578326871, details={'was_impossible': False}),
#  Prediction(uid='A23BH24MXOPUZU', iid='Movie20', r_ui=0.0, est=-0.018711038651908707, details={'was_impossible': False}),
#  Prediction(uid='A1I74FIEYJM9EP', iid='Movie152', r_ui=0.0, est=0.015856564855250443, details={'was_impossible': False}),
#  Prediction(uid='AMSVHFJWBLPXX', iid='Movie101', r_ui=0.0, est=0.006566725134732998, details={'was_impossible': False}),
#  Prediction(uid='A2AKR3QR28W09U', iid='Movie103', r_ui=0.0, est=-0.16842106496673193, details={'was_impossible': False}),
#  Prediction(uid='A2FA1MQ6AAVJBV', iid='Movie178', r_ui=0.0, est=0.0012592974980480953, details={'was_impossible': False}),
#  Prediction(uid='A3SPENWJVW3OBC', iid='Movie174', r_ui=0.0, est=0.01662277011308877, details={'was_impossible': False}),
#  Prediction(uid='A21XVS00AIENLX', iid='Movie168', r_ui=0.0, est=-0.009373233127760283, details={'was_impossible': False}),
#  Prediction(uid='A8O7G2UCUXPHK', iid='Movie193', r_ui=0.0, est=-0.0034172525951368105, details={'was_impossible': False}),
#  Prediction(uid='AOYTGNBDDE5PE', iid='Movie190', r_ui=0.0, est=0.017512878400271603, details={'was_impossible': False}),
#  Prediction(uid='A11QU8E1MR0B8H', iid='Movie84', r_ui=0.0, est=-0.008202922915995448, details={'was_impossible': False}),
#  Prediction(uid='A2OKAPRYQXPWDD', iid='Movie83', r_ui=0.0, est=0.002203215225701438, details={'was_impossible': False}),
#  Prediction(uid='A3SU3TXON36T0X', iid='Movie118', r_ui=0.0, est=0.0004764673795545349, details={'was_impossible': False}),
#  Prediction(uid='A3QUKRZRLKUIBU', iid='Movie115', r_ui=0.0, est=0.0005120165213226002, details={'was_impossible': False}),
#  Prediction(uid='AYUQRYH51OHXU', iid='Movie42', r_ui=0.0, est=-0.004723617092469379, details={'was_impossible': False}),
#  Prediction(uid='A3HKTEWQ3GTJK7', iid='Movie50', r_ui=0.0, est=0.010627749305649914, details={'was_impossible': False}),
#  Prediction(uid='A2G7OQHFIDEVN7', iid='Movie1', r_ui=0.0, est=-0.022379628045312128, details={'was_impossible': False}),
#  Prediction(uid='A2S6UVLBE48EY2', iid='Movie182', r_ui=0.0, est=0.008776104248120031, details={'was_impossible': False}),
#  Prediction(uid='A1QQPIUXWD4G0Z', iid='Movie35', r_ui=0.0, est=0.0011361638594205026, details={'was_impossible': False}),
#  Prediction(uid='ARRWFEWVXBAG7', iid='Movie85', r_ui=0.0, est=0.001697505547383571, details={'was_impossible': False}),
#  Prediction(uid='A1CDNTB7377YH2', iid='Movie191', r_ui=0.0, est=0.012823272589050028, details={'was_impossible': False}),
#  Prediction(uid='ARRJQJ57SADZK', iid='Movie2', r_ui=0.0, est=-0.009345603931776969, details={'was_impossible': False}),
#  Prediction(uid='A37JKM7EFD0DIQ', iid='Movie89', r_ui=0.0, est=0.03720059386798402, details={'was_impossible': False}),
#  Prediction(uid='A6YK7TEYVSSA3', iid='Movie83', r_ui=0.0, est=0.003422755885758466, details={'was_impossible': False}),
#  Prediction(uid='A1RO2KIKSALCEE', iid='Movie46', r_ui=0.0, est=-0.002650108534160367, details={'was_impossible': False}),
#  Prediction(uid='A2NJ4DIOKU2ALC', iid='Movie137', r_ui=0.0, est=0.020305324743078224, details={'was_impossible': False}),
#  Prediction(uid='A1ZDMQVKLSXL27', iid='Movie31', r_ui=0.0, est=-0.010567773703562766, details={'was_impossible': False}),
#  Prediction(uid='A2MHJJ4HXN8X40', iid='Movie110', r_ui=0.0, est=-0.006840202911572835, details={'was_impossible': False}),
#  Prediction(uid='A5CSVNVV2XBE7', iid='Movie126', r_ui=0.0, est=-0.004163111415828036, details={'was_impossible': False}),
#  Prediction(uid='AD1BYQD22QPNC', iid='Movie43', r_ui=0.0, est=0.015069143103342952, details={'was_impossible': False}),
#  Prediction(uid='A2GOAEF0ZRNG13', iid='Movie98', r_ui=0.0, est=-0.01757096377990064, details={'was_impossible': False}),
#  Prediction(uid='AJB46S6CRWIXB', iid='Movie126', r_ui=0.0, est=-0.006622694952331587, details={'was_impossible': False}),
#  Prediction(uid='A2AOCMTCD0JAAT', iid='Movie187', r_ui=0.0, est=0.0020523840480013433, details={'was_impossible': False}),
#  Prediction(uid='AOCDHPWEPU6U5', iid='Movie191', r_ui=0.0, est=0.026057298323620692, details={'was_impossible': False}),
#  Prediction(uid='A2505LX5IKI01E', iid='Movie18', r_ui=0.0, est=0.01275858928282858, details={'was_impossible': False}),
#  Prediction(uid='A3TYI6D70F332B', iid='Movie126', r_ui=0.0, est=-0.001309828999772833, details={'was_impossible': False}),
#  Prediction(uid='AGO7Z0L7LK0JE', iid='Movie19', r_ui=0.0, est=0.00595642812331354, details={'was_impossible': False}),
#  Prediction(uid='A1DTCJV6KOMJOA', iid='Movie2', r_ui=0.0, est=0.001128465217279384, details={'was_impossible': False}),
#  Prediction(uid='AH0LBBZPIZJRP', iid='Movie134', r_ui=0.0, est=-0.001113623803540964, details={'was_impossible': False}),
#  Prediction(uid='A2K3U6DVQQRES3', iid='Movie21', r_ui=0.0, est=-0.0017957847313789799, details={'was_impossible': False}),
#  Prediction(uid='AOIYU1W84RIUB', iid='Movie99', r_ui=0.0, est=-0.009907027472542795, details={'was_impossible': False}),
#  Prediction(uid='A2X2QV59LS3VV1', iid='Movie4', r_ui=0.0, est=0.0040980393705658535, details={'was_impossible': False}),
#  Prediction(uid='AKD39TI51YZ2W', iid='Movie116', r_ui=0.0, est=-0.006311389053367256, details={'was_impossible': False}),
#  Prediction(uid='AL8Q982DJQ9P', iid='Movie100', r_ui=0.0, est=-0.01367764659808457, details={'was_impossible': False}),
#  Prediction(uid='A3F6WEP0SICVWS', iid='Movie100', r_ui=0.0, est=0.02836506789257287, details={'was_impossible': False}),
#  Prediction(uid='A88DLAA1FBZVZ', iid='Movie67', r_ui=0.0, est=-0.01471987876501446, details={'was_impossible': False}),
#  Prediction(uid='A4P2P0GAMR7XX', iid='Movie188', r_ui=0.0, est=0.010401608698401787, details={'was_impossible': False}),
#  Prediction(uid='A20CVHV28RL5NR', iid='Movie13', r_ui=0.0, est=0.003437914098539885, details={'was_impossible': False}),
#  Prediction(uid='A2869WCKQA2NNW', iid='Movie110', r_ui=0.0, est=0.009798495025612475, details={'was_impossible': False}),
#  Prediction(uid='A6GR90J7UNLOL', iid='Movie32', r_ui=0.0, est=0.012427628884408293, details={'was_impossible': False}),
#  Prediction(uid='A3QC8Z61AN7TDE', iid='Movie55', r_ui=0.0, est=0.006058459899130231, details={'was_impossible': False}),
#  Prediction(uid='A3SU3TXON36T0X', iid='Movie52', r_ui=0.0, est=-0.025994556824018078, details={'was_impossible': False}),
#  Prediction(uid='A1UE3O7AJ71FVE', iid='Movie88', r_ui=0.0, est=-0.007342589477182138, details={'was_impossible': False}),
#  Prediction(uid='A3FOJHZF01BKXW', iid='Movie40', r_ui=0.0, est=0.012830011450830625, details={'was_impossible': False}),
#  Prediction(uid='A2PYFT21RURQF1', iid='Movie123', r_ui=0.0, est=0.0024644439170087296, details={'was_impossible': False}),
#  Prediction(uid='A2LD0YL2U1P058', iid='Movie10', r_ui=0.0, est=-0.003962858656246793, details={'was_impossible': False}),
#  Prediction(uid='A3AMC7DA1WUK1P', iid='Movie77', r_ui=0.0, est=-0.0022585205096743444, details={'was_impossible': False}),
#  Prediction(uid='A3VERR8USXCHS4', iid='Movie121', r_ui=0.0, est=0.02583169572127142, details={'was_impossible': False}),
#  Prediction(uid='A2BSICFM0PXUDE', iid='Movie82', r_ui=0.0, est=0.007833475515204302, details={'was_impossible': False}),
#  Prediction(uid='A2QLBNC9F4BDU', iid='Movie66', r_ui=0.0, est=0.003960121500364178, details={'was_impossible': False}),
#  Prediction(uid='A37KYHZ59KI9E0', iid='Movie183', r_ui=0.0, est=-0.0003252725558546832, details={'was_impossible': False}),
#  Prediction(uid='A1968MG1IR517T', iid='Movie118', r_ui=0.0, est=-0.0024845708378444797, details={'was_impossible': False}),
#  Prediction(uid='A3ADV4DII19PA7', iid='Movie102', r_ui=0.0, est=-0.00701374378562436, details={'was_impossible': False}),
#  Prediction(uid='AJKBDG1OBMGB8', iid='Movie85', r_ui=0.0, est=-0.01407803431993404, details={'was_impossible': False}),
#  Prediction(uid='A2U428KPX46QZN', iid='Movie176', r_ui=0.0, est=-0.006167804380508901, details={'was_impossible': False}),
#  Prediction(uid='A50CM8OWGJF51', iid='Movie46', r_ui=0.0, est=0.017440999168497395, details={'was_impossible': False}),
#  Prediction(uid='A3HX8FEFIDG5C', iid='Movie105', r_ui=0.0, est=0.0058726965123758745, details={'was_impossible': False}),
#  Prediction(uid='A2VBT1E9ZSH8KF', iid='Movie111', r_ui=0.0, est=0.08631768459321787, details={'was_impossible': False}),
#  Prediction(uid='A2G1S8AZFUQMWG', iid='Movie107', r_ui=0.0, est=0.03581307914840792, details={'was_impossible': False}),
#  Prediction(uid='A3EYEAQKYRIH1E', iid='Movie145', r_ui=0.0, est=0.010221779017476784, details={'was_impossible': False}),
#  Prediction(uid='AZGQ8DMTSUM0E', iid='Movie45', r_ui=0.0, est=-0.008819588491148833, details={'was_impossible': False}),
#  Prediction(uid='A4MRHFD9F9LNR', iid='Movie49', r_ui=0.0, est=0.004574389692602487, details={'was_impossible': False}),
#  Prediction(uid='A2FW98KPY182GJ', iid='Movie6', r_ui=0.0, est=0.005394741817273729, details={'was_impossible': False}),
#  Prediction(uid='A256DT2H3A53XZ', iid='Movie4', r_ui=0.0, est=-0.010639053397937248, details={'was_impossible': False}),
#  Prediction(uid='A2GXBHH8BW02CW', iid='Movie114', r_ui=0.0, est=0.01324866111444356, details={'was_impossible': False}),
#  Prediction(uid='A1ZAQHMCCT297C', iid='Movie133', r_ui=0.0, est=0.019816819462793678, details={'was_impossible': False}),
#  Prediction(uid='A513VEBQYIFTV', iid='Movie86', r_ui=0.0, est=0.021448599110492683, details={'was_impossible': False}),
#  Prediction(uid='A1Z3K3GOK50S42', iid='Movie133', r_ui=0.0, est=0.003710487927538697, details={'was_impossible': False}),
#  Prediction(uid='A3DZCNEU21MB6L', iid='Movie60', r_ui=0.0, est=0.016669780404513723, details={'was_impossible': False}),
#  Prediction(uid='A2CEHLOIGAP79M', iid='Movie159', r_ui=0.0, est=7.315392509532614e-05, details={'was_impossible': False}),
#  Prediction(uid='ACC5VPZHR3B5Q', iid='Movie173', r_ui=0.0, est=0.037241238055874426, details={'was_impossible': False}),
#  Prediction(uid='A14ILXO42WSFJQ', iid='Movie37', r_ui=0.0, est=0.0021539422211542814, details={'was_impossible': False}),
#  Prediction(uid='A1FSSPOTGA8E5S', iid='Movie37', r_ui=0.0, est=-0.015991701547131365, details={'was_impossible': False}),
#  Prediction(uid='A19UYFKL0OJO4Q', iid='Movie162', r_ui=0.0, est=0.023829513370795308, details={'was_impossible': False}),
#  Prediction(uid='A1NI0VOVXZBM7Y', iid='Movie54', r_ui=0.0, est=0.001980275216663774, details={'was_impossible': False}),
#  Prediction(uid='A39JGI1L8BBLAO', iid='Movie182', r_ui=0.0, est=0.03522705541009463, details={'was_impossible': False}),
#  Prediction(uid='A229GOA71T7D4N', iid='Movie69', r_ui=0.0, est=0.004541499738905053, details={'was_impossible': False}),
#  Prediction(uid='A2LESFHD1KKWGM', iid='Movie48', r_ui=0.0, est=0.000194374001885933, details={'was_impossible': False}),
#  Prediction(uid='AHO1RZ25MO7E9', iid='Movie178', r_ui=0.0, est=-0.027261003442225817, details={'was_impossible': False}),
#  Prediction(uid='A9S3ZODQ7LX9W', iid='Movie52', r_ui=0.0, est=-0.012706294774988303, details={'was_impossible': False}),
#  Prediction(uid='AH0NP02KOSIWU', iid='Movie201', r_ui=0.0, est=-0.002741918274921762, details={'was_impossible': False}),
#  Prediction(uid='ASMOI1DCK0K93', iid='Movie105', r_ui=0.0, est=0.006823543639603358, details={'was_impossible': False}),
#  Prediction(uid='A595T15OO91DC', iid='Movie93', r_ui=0.0, est=0.02040225215455882, details={'was_impossible': False}),
#  Prediction(uid='A2YP1HYB6Q0JEQ', iid='Movie90', r_ui=0.0, est=0.09560669996772608, details={'was_impossible': False}),
#  Prediction(uid='ALXFQ91OW9ZTC', iid='Movie34', r_ui=0.0, est=0.0033693820301654576, details={'was_impossible': False}),
#  Prediction(uid='A1U00P6GKI537A', iid='Movie68', r_ui=0.0, est=-0.0039924197761527225, details={'was_impossible': False}),
#  Prediction(uid='A1845IJB63D5H7', iid='Movie152', r_ui=0.0, est=0.001281033844330981, details={'was_impossible': False}),
#  Prediction(uid='A2P7RSRNEKRWSJ', iid='Movie119', r_ui=0.0, est=0.037787485399898735, details={'was_impossible': False}),
#  Prediction(uid='A2BXVL1JW115LS', iid='Movie138', r_ui=0.0, est=-0.007447640695119606, details={'was_impossible': False}),
#  Prediction(uid='A2ADTTN16H3MJ7', iid='Movie163', r_ui=0.0, est=-0.014153633027704116, details={'was_impossible': False}),
#  Prediction(uid='A1QQPIUXWD4G0Z', iid='Movie178', r_ui=0.0, est=0.0021175264304527097, details={'was_impossible': False}),
#  Prediction(uid='AZBR3A600VWOX', iid='Movie182', r_ui=0.0, est=0.06176569077225125, details={'was_impossible': False}),
#  Prediction(uid='A1IYEBTXNWTNLY', iid='Movie86', r_ui=0.0, est=0.0007347554536218937, details={'was_impossible': False}),
#  Prediction(uid='A2ZLZ2G39EDNF3', iid='Movie194', r_ui=0.0, est=0.061598466769630544, details={'was_impossible': False}),
#  Prediction(uid='AEY85DNREUBBJ', iid='Movie102', r_ui=0.0, est=-0.0014928312566191426, details={'was_impossible': False}),
#  Prediction(uid='A2C3AL99R0ZK5L', iid='Movie2', r_ui=0.0, est=0.004002604594072423, details={'was_impossible': False}),
#  Prediction(uid='A4G4HE8KQ0R7X', iid='Movie172', r_ui=0.0, est=-0.006933717375083637, details={'was_impossible': False}),
#  Prediction(uid='AZZ1KF8RAO1BR', iid='Movie70', r_ui=0.0, est=-0.006942188701236862, details={'was_impossible': False}),
#  Prediction(uid='A3EOHYIHQM3KK', iid='Movie48', r_ui=0.0, est=-0.022681451665403918, details={'was_impossible': False}),
#  Prediction(uid='A5P6XVNXJBX7E', iid='Movie181', r_ui=0.0, est=-0.009371354316356717, details={'was_impossible': False}),
# ...
#  Prediction(uid='A2X1A3MY0EEESU', iid='Movie121', r_ui=0.0, est=0.020775622404314298, details={'was_impossible': False}),
#  Prediction(uid='A1ITJWI9QCHL0X', iid='Movie36', r_ui=0.0, est=0.004528042726881232, details={'was_impossible': False}),
#  Prediction(uid='A29CUCGRX04TS8', iid='Movie108', r_ui=0.0, est=0.0012691729617309022, details={'was_impossible': False}),
#  Prediction(uid='A2I0X9N2RH7R7X', iid='Movie162', r_ui=0.0, est=0.06688080890094783, details={'was_impossible': False}),
#  Prediction(uid='A33WE1Z6QPUM0Z', iid='Movie7', r_ui=0.0, est=0.02007009562856865, details={'was_impossible': False}),
#  Prediction(uid='ACZMD9Q8FHS9I', iid='Movie46', r_ui=0.0, est=-0.0008641290410966729, details={'was_impossible': False}),
#  Prediction(uid='AGM43L35FKQB9', iid='Movie8', r_ui=0.0, est=-0.014628813463144708, details={'was_impossible': False}),
#  Prediction(uid='AQEQ3HHAKDLAH', iid='Movie53', r_ui=0.0, est=-0.011212437980313794, details={'was_impossible': False}),
#  Prediction(uid='A1E7RPUT3P1PY', iid='Movie184', r_ui=0.0, est=0.056941114664330605, details={'was_impossible': False}),
#  Prediction(uid='ALG89TL23H7DF', iid='Movie153', r_ui=0.0, est=0.0027513021451706088, details={'was_impossible': False}),
#  Prediction(uid='A3IKMJSA3THEU', iid='Movie177', r_ui=0.0, est=0.007155909795069526, details={'was_impossible': False}),
#  Prediction(uid='A2LT6H33UHXYIL', iid='Movie174', r_ui=0.0, est=-0.013185856968636278, details={'was_impossible': False}),
#  Prediction(uid='AIRHRV3D8X4J1', iid='Movie36', r_ui=0.0, est=-0.002839621711143936, details={'was_impossible': False}),
#  Prediction(uid='A1VONCVB0ANIEH', iid='Movie26', r_ui=0.0, est=-0.008883284798242741, details={'was_impossible': False}),
#  Prediction(uid='A3DGEEVLH5GGKW', iid='Movie6', r_ui=0.0, est=0.0032868756084138973, details={'was_impossible': False}),
#  Prediction(uid='A3Q0JTHPLOZF64', iid='Movie122', r_ui=0.0, est=0.016362575995028994, details={'was_impossible': False}),
#  Prediction(uid='A1AUO4FIP0IYZ8', iid='Movie166', r_ui=0.0, est=0.027395266285121345, details={'was_impossible': False}),
#  Prediction(uid='A3S8A2K617Y4B5', iid='Movie57', r_ui=0.0, est=0.006211057493725303, details={'was_impossible': False}),
#  Prediction(uid='A2EDZH51XHFA9B', iid='Movie92', r_ui=0.0, est=-0.017191591010380147, details={'was_impossible': False}),
#  Prediction(uid='A330Q95YYRB0VL', iid='Movie40', r_ui=0.0, est=0.001523953981538373, details={'was_impossible': False}),
#  Prediction(uid='A3VGR552UGKS83', iid='Movie120', r_ui=0.0, est=0.025018414889009133, details={'was_impossible': False}),
#  Prediction(uid='A3LXDOWNIWRXDW', iid='Movie123', r_ui=0.0, est=-0.01237641456259353, details={'was_impossible': False}),
#  Prediction(uid='A2B8GXSCB1R05T', iid='Movie90', r_ui=0.0, est=0.012320829914945541, details={'was_impossible': False}),
#  Prediction(uid='A1YWBPN6CIZU7N', iid='Movie30', r_ui=0.0, est=-0.005723839616821325, details={'was_impossible': False}),
#  Prediction(uid='A3R2I2OVAJ5MAC', iid='Movie149', r_ui=0.0, est=0.0034852305461914312, details={'was_impossible': False}),
#  Prediction(uid='A1PUT35XF7KVD5', iid='Movie90', r_ui=0.0, est=-0.001990472923484088, details={'was_impossible': False}),
#  Prediction(uid='A24AEACWYIKCN7', iid='Movie122', r_ui=0.0, est=-0.010208135734423918, details={'was_impossible': False}),
#  Prediction(uid='ADEC4ISEGKTR2', iid='Movie161', r_ui=0.0, est=0.06191201690873438, details={'was_impossible': False}),
#  Prediction(uid='A2UW5WY3UREXNP', iid='Movie2', r_ui=0.0, est=-0.016711800677044142, details={'was_impossible': False}),
#  Prediction(uid='A116NVCXW1F7N1', iid='Movie53', r_ui=0.0, est=0.003554222770904669, details={'was_impossible': False}),
#  Prediction(uid='A2Q6Q0BHHRUMS9', iid='Movie96', r_ui=0.0, est=-0.023401916940982925, details={'was_impossible': False}),
#  Prediction(uid='A29CUCGRX04TS8', iid='Movie33', r_ui=0.0, est=-0.013753272574261732, details={'was_impossible': False}),
#  Prediction(uid='A3TLX5CLH7NEL1', iid='Movie110', r_ui=0.0, est=0.003995971141120158, details={'was_impossible': False}),
#  Prediction(uid='A3W3EB24TA5BSI', iid='Movie108', r_ui=0.0, est=0.1499857024820348, details={'was_impossible': False}),
#  Prediction(uid='ALEFQIC7EDSXV', iid='Movie68', r_ui=0.0, est=-0.01475743278483388, details={'was_impossible': False}),
#  Prediction(uid='A2YRWE73IZYN0P', iid='Movie79', r_ui=0.0, est=0.009241253532384253, details={'was_impossible': False}),
#  Prediction(uid='AI01VIROP8MHI', iid='Movie182', r_ui=0.0, est=0.02452057579181588, details={'was_impossible': False}),
#  Prediction(uid='AV3UWBH6K0ETD', iid='Movie55', r_ui=0.0, est=-0.0024273843213351576, details={'was_impossible': False}),
#  Prediction(uid='ANOK127P27F11', iid='Movie183', r_ui=0.0, est=-0.013039400469819329, details={'was_impossible': False}),
#  Prediction(uid='A5CSVNVV2XBE7', iid='Movie37', r_ui=0.0, est=0.0022871697436230853, details={'was_impossible': False}),
#  Prediction(uid='A2OBH7H02DP67O', iid='Movie162', r_ui=0.0, est=0.03346673607612738, details={'was_impossible': False}),
#  Prediction(uid='A2JLGK8JAJ8E9C', iid='Movie148', r_ui=0.0, est=-0.0009872940525350593, details={'was_impossible': False}),
#  Prediction(uid='A2A7EKKEKLWYZF', iid='Movie3', r_ui=0.0, est=-0.00919076825959353, details={'was_impossible': False}),
#  Prediction(uid='A1O3QX86HSIW4E', iid='Movie115', r_ui=0.0, est=0.08328259669372029, details={'was_impossible': False}),
#  Prediction(uid='APAR29GJ0L8IO', iid='Movie198', r_ui=0.0, est=0.0014329677444693267, details={'was_impossible': False}),
#  Prediction(uid='A3CCD9A0252A51', iid='Movie11', r_ui=0.0, est=-0.011425619705009327, details={'was_impossible': False}),
#  Prediction(uid='A2RTWCLPRY10EE', iid='Movie45', r_ui=0.0, est=0.003305391482662401, details={'was_impossible': False}),
#  Prediction(uid='A1QP8CVESJ1FP7', iid='Movie83', r_ui=0.0, est=0.012364681539038802, details={'was_impossible': False}),
#  Prediction(uid='A3QTP2CI1BDV0M', iid='Movie172', r_ui=0.0, est=0.01336035264449853, details={'was_impossible': False}),
#  Prediction(uid='A22G01AXB3H5TY', iid='Movie84', r_ui=0.0, est=0.0047657485058123505, details={'was_impossible': False}),
#  Prediction(uid='AAL9EWX1NDS73', iid='Movie175', r_ui=0.0, est=-0.0033154199891962666, details={'was_impossible': False}),
#  Prediction(uid='A2G4QGOS1I6IWQ', iid='Movie109', r_ui=0.0, est=0.029757714165535187, details={'was_impossible': False}),
#  Prediction(uid='A1JAPNAT23ATR2', iid='Movie142', r_ui=0.0, est=-0.006442927810726529, details={'was_impossible': False}),
#  Prediction(uid='A2EQL2BP6IYEGX', iid='Movie60', r_ui=0.0, est=0.0007744530045443732, details={'was_impossible': False}),
#  Prediction(uid='A1B8BEPX1UJ8I4', iid='Movie33', r_ui=0.0, est=-0.011077678885550002, details={'was_impossible': False}),
#  Prediction(uid='A3VVDS4FJ0367B', iid='Movie149', r_ui=0.0, est=-0.011463733737374637, details={'was_impossible': False}),
#  Prediction(uid='A3JSROIZ1SFTS', iid='Movie66', r_ui=0.0, est=-0.003166804192529238, details={'was_impossible': False}),
#  Prediction(uid='A19DEOGB7LXQJS', iid='Movie14', r_ui=0.0, est=0.003628927289195616, details={'was_impossible': False}),
#  Prediction(uid='A1LCRPEBER4ETQ', iid='Movie175', r_ui=0.0, est=-0.01921746202302832, details={'was_impossible': False}),
#  Prediction(uid='AK5UC249N167', iid='Movie157', r_ui=0.0, est=0.010818872127737134, details={'was_impossible': False}),
#  Prediction(uid='A3BOOBEERUBMR2', iid='Movie190', r_ui=0.0, est=0.015650454874643227, details={'was_impossible': False}),
#  Prediction(uid='A15TNUM2PBS6F0', iid='Movie146', r_ui=0.0, est=0.0023214114142886544, details={'was_impossible': False}),
#  Prediction(uid='A2OMPWTXYQ2XAN', iid='Movie54', r_ui=0.0, est=0.004916182759095555, details={'was_impossible': False}),
#  Prediction(uid='A3STPLN7ROFSAG', iid='Movie132', r_ui=0.0, est=0.011183703939573242, details={'was_impossible': False}),
#  Prediction(uid='A1TPFZ44VAVDWZ', iid='Movie104', r_ui=0.0, est=0.02913570897496065, details={'was_impossible': False}),
#  Prediction(uid='A8VV10NKQ11QO', iid='Movie62', r_ui=0.0, est=-0.003235022834414014, details={'was_impossible': False}),
#  Prediction(uid='AISZDNSRO86D6', iid='Movie69', r_ui=0.0, est=-0.015158043766440032, details={'was_impossible': False}),
#  Prediction(uid='AS3BJ3X86WERQ', iid='Movie79', r_ui=0.0, est=-0.0077655730502868, details={'was_impossible': False}),
#  Prediction(uid='A2U559EYMXTBOB', iid='Movie141', r_ui=0.0, est=0.01011719976776071, details={'was_impossible': False}),
#  Prediction(uid='A1HP3B92A3JDQ1', iid='Movie185', r_ui=0.0, est=0.005784553053336694, details={'was_impossible': False}),
#  Prediction(uid='A20CMHT4LYLHZH', iid='Movie63', r_ui=0.0, est=-0.008612184134634937, details={'was_impossible': False}),
#  Prediction(uid='A17DHMBDJMYVU1', iid='Movie56', r_ui=0.0, est=0.0008704380369466413, details={'was_impossible': False}),
#  Prediction(uid='A1Y81TTIF0F5GX', iid='Movie109', r_ui=0.0, est=0.004286532742241889, details={'was_impossible': False}),
#  Prediction(uid='AMK96SSKCHGL3', iid='Movie197', r_ui=0.0, est=0.013395517014822556, details={'was_impossible': False}),
#  Prediction(uid='A22WZZUZ12O62V', iid='Movie67', r_ui=0.0, est=-0.016386806257419062, details={'was_impossible': False}),
#  Prediction(uid='A2W59U8J636WQP', iid='Movie135', r_ui=0.0, est=0.0026973870421489465, details={'was_impossible': False}),
#  Prediction(uid='A3KGAJ86I4T73J', iid='Movie144', r_ui=0.0, est=0.010872321730031054, details={'was_impossible': False}),
#  Prediction(uid='A1PUBMDKB4RYWG', iid='Movie22', r_ui=0.0, est=0.007028371975903891, details={'was_impossible': False}),
#  Prediction(uid='A31II9BZQ4GG32', iid='Movie194', r_ui=0.0, est=0.03454211392565654, details={'was_impossible': False}),
#  Prediction(uid='A1B3F8V019CODC', iid='Movie64', r_ui=0.0, est=1.5476016561599693e-05, details={'was_impossible': False}),
#  Prediction(uid='A2W8SXY9PZHKIW', iid='Movie71', r_ui=0.0, est=-0.008750235620073932, details={'was_impossible': False}),
#  Prediction(uid='A22BPC7LRSGSYQ', iid='Movie122', r_ui=0.0, est=0.028627569130263986, details={'was_impossible': False}),
#  Prediction(uid='A3GA09FYFKL4EY', iid='Movie3', r_ui=0.0, est=-0.00736592653917767, details={'was_impossible': False}),
#  Prediction(uid='A24WSQSHED8C2Z', iid='Movie70', r_ui=0.0, est=-0.0023841495476810692, details={'was_impossible': False}),
#  Prediction(uid='A1YF0QVUV2IFQU', iid='Movie116', r_ui=0.0, est=-0.01048351376294021, details={'was_impossible': False}),
#  Prediction(uid='A3CYCKP0XPX98V', iid='Movie99', r_ui=0.0, est=0.015590128184543861, details={'was_impossible': False}),
#  Prediction(uid='A1WS0SZ4HN7YZ5', iid='Movie9', r_ui=0.0, est=0.002894630667269471, details={'was_impossible': False}),
#  Prediction(uid='A19VKVJSY2HSXE', iid='Movie169', r_ui=0.0, est=-0.008954000171522258, details={'was_impossible': False}),
#  Prediction(uid='A12WCC7NWINKEM', iid='Movie115', r_ui=0.0, est=-0.006994922156187355, details={'was_impossible': False}),
#  Prediction(uid='A2726ZHKMUE6K1', iid='Movie181', r_ui=0.0, est=-0.01135769007398113, details={'was_impossible': False}),
#  Prediction(uid='A4F5E6CDHEFU', iid='Movie163', r_ui=0.0, est=-0.0015406732068790063, details={'was_impossible': False}),
#  Prediction(uid='A3I2GBE2KGQV1U', iid='Movie46', r_ui=0.0, est=0.0011331894030464085, details={'was_impossible': False}),
#  Prediction(uid='AWIF8AR75LL9L', iid='Movie100', r_ui=0.0, est=0.008715153986572854, details={'was_impossible': False}),
#  Prediction(uid='A1IBQJXZB4P3XE', iid='Movie142', r_ui=0.0, est=-0.00037139649953488174, details={'was_impossible': False}),
#  Prediction(uid='A2OHIBSF4XKTDC', iid='Movie197', r_ui=0.0, est=0.013109627523978595, details={'was_impossible': False}),
#  Prediction(uid='ASPMZOKXF4ATZ', iid='Movie30', r_ui=0.0, est=-0.0026019676503215017, details={'was_impossible': False}),
#  Prediction(uid='AMQZ40Z0NGMAE', iid='Movie140', r_ui=0.0, est=0.4421831118421409, details={'was_impossible': False}),
#  Prediction(uid='A39KSHSIHELFYW', iid='Movie81', r_ui=0.0, est=0.04133495833154255, details={'was_impossible': False}),
#  Prediction(uid='AQ6AGWKWMTY8H', iid='Movie159', r_ui=0.0, est=0.02354478205234356, details={'was_impossible': False}),
#  Prediction(uid='A3EKSOZGHAD9F4', iid='Movie162', r_ui=0.0, est=0.06761472565360904, details={'was_impossible': False}),
#  Prediction(uid='A3UT41TWD7N0D5', iid='Movie140', r_ui=0.0, est=0.2791441496279541, details={'was_impossible': False}),
#  Prediction(uid='A202QOQCQMWCBI', iid='Movie164', r_ui=0.0, est=0.006258085197750063, details={'was_impossible': False}),
#  Prediction(uid='A2WVIHTAL91VIS', iid='Movie32', r_ui=0.0, est=-0.013979251816710114, details={'was_impossible': False}),
#  Prediction(uid='A37DRT5HJQDTSF', iid='Movie149', r_ui=0.0, est=0.024522087529853298, details={'was_impossible': False}),
#  Prediction(uid='ARGJ5T077BPQ4', iid='Movie29', r_ui=0.0, est=0.5182519108548931, details={'was_impossible': False}),
#  Prediction(uid='A127O07CONBWIR', iid='Movie41', r_ui=0.0, est=-0.0032269426348370267, details={'was_impossible': False}),
#  Prediction(uid='A2726ZHKMUE6K1', iid='Movie57', r_ui=0.0, est=-0.01613405592422268, details={'was_impossible': False}),
#  Prediction(uid='A573HCFMWNT60', iid='Movie99', r_ui=0.0, est=0.00020467184780414982, details={'was_impossible': False}),
#  Prediction(uid='A18SB6YZXTOF7W', iid='Movie134', r_ui=0.0, est=0.013881617999643048, details={'was_impossible': False}),
#  Prediction(uid='AMH3MVGRC2YG', iid='Movie20', r_ui=0.0, est=-0.010971398573791147, details={'was_impossible': False}),
#  Prediction(uid='A3J0AQUK0I4C60', iid='Movie31', r_ui=0.0, est=0.0008002996423437381, details={'was_impossible': False}),
#  Prediction(uid='AJ561ELTCUY6P', iid='Movie127', r_ui=2.0, est=2.0089875594730557, details={'was_impossible': False}),
#  Prediction(uid='A2U5VZLV0IK40J', iid='Movie96', r_ui=0.0, est=-0.010918767489870307, details={'was_impossible': False}),
#  Prediction(uid='A3Q9A5BLDRU2OH', iid='Movie191', r_ui=0.0, est=0.015129980032023926, details={'was_impossible': False}),
#  Prediction(uid='A363QRXP83K8ZE', iid='Movie32', r_ui=0.0, est=-0.009576434239767506, details={'was_impossible': False}),
#  Prediction(uid='A1ZLUMSWANRYXL', iid='Movie2', r_ui=0.0, est=-0.009348458445596286, details={'was_impossible': False}),
#  Prediction(uid='A2ZFAYA9NKP2SA', iid='Movie139', r_ui=0.0, est=0.0024711303045368282, details={'was_impossible': False}),
#  Prediction(uid='A1R2XZWQ6NM5M1', iid='Movie176', r_ui=0.0, est=-0.02291309922750573, details={'was_impossible': False}),
#  Prediction(uid='A1RG3EPDJD26UU', iid='Movie41', r_ui=0.0, est=0.014605640528968067, details={'was_impossible': False}),
#  Prediction(uid='A39LLNTVTUMP2U', iid='Movie10', r_ui=0.0, est=0.01039570464242967, details={'was_impossible': False}),
#  Prediction(uid='A13NHSHPBRVN72', iid='Movie51', r_ui=0.0, est=-0.0006800827567563505, details={'was_impossible': False}),
#  Prediction(uid='A3M1I3T6RCU13B', iid='Movie144', r_ui=0.0, est=0.006556917552127395, details={'was_impossible': False}),
#  Prediction(uid='A2IS1BTDQ6MGX', iid='Movie60', r_ui=0.0, est=-0.002430797261992579, details={'was_impossible': False}),
#  Prediction(uid='A2E7HT57OEJCB', iid='Movie50', r_ui=0.0, est=-0.015087944966390321, details={'was_impossible': False}),
#  Prediction(uid='A36BJGD1LAHY0C', iid='Movie112', r_ui=0.0, est=0.049056236347958304, details={'was_impossible': False}),
#  Prediction(uid='A1VK3WQ4CRH9RO', iid='Movie182', r_ui=0.0, est=-4.5170782473569204e-05, details={'was_impossible': False}),
#  Prediction(uid='A27EK1P0L7A1LA', iid='Movie193', r_ui=0.0, est=0.04216194199430712, details={'was_impossible': False}),
#  Prediction(uid='A1CIW2OEVAJRM2', iid='Movie42', r_ui=0.0, est=-0.01162383764865238, details={'was_impossible': False}),
#  Prediction(uid='AWNBZSEZ9P8BE', iid='Movie146', r_ui=0.0, est=0.016712884442817266, details={'was_impossible': False}),
#  Prediction(uid='A88A8EX949W5V', iid='Movie115', r_ui=0.0, est=0.01765134195096607, details={'was_impossible': False}),
#  Prediction(uid='AQ2UXJITW1JRT', iid='Movie120', r_ui=0.0, est=0.0038186458032076764, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# #### Q3 Make predictions on the test data

# %% [markdown]
# #### So in predict case the estimate was a score of 0. But in order to recommend the best rating to users, we need to find n items that have the highest predicted score.

# %%
# let make a predication

userID = 'APUVMJA6Q7YZP'
MovieName = 'Movie1'
MovieRating = 0.0

pred = algo.predict(userID, MovieName, r_ui=MovieRating, verbose=True)

print(pred.est)
# Out:
# user: APUVMJA6Q7YZP item: Movie1     r_ui = 0.00   est = 0.04   {'was_impossible': False}
# 0.04134679368893357

# %%
userID = 'A1IMQ9WMFYKWH5'
MovieName = 'Movie127'
MovieRating = 4.5

print('User ', userID, algo.predict(userID, MovieName, r_ui=MovieRating, verbose=True).est)

userID = 'A3R5OBKS7OM2IR'

print('User ', userID, algo.predict(userID, MovieName, r_ui=MovieRating, verbose=True).est)
# Out:
# user: A1IMQ9WMFYKWH5 item: Movie127   r_ui = 4.50   est = 0.43   {'was_impossible': False}
# User  A1IMQ9WMFYKWH5 0.4289237183017107
# user: A3R5OBKS7OM2IR item: Movie127   r_ui = 4.50   est = 0.33   {'was_impossible': False}
# User  A3R5OBKS7OM2IR 0.3292819847646751

# %%
# calculate the accuracy using RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.2890
# 0.28896912211758213

# %% [markdown]
# #### Repeat it for test_size 0.25

# %%
# we can repeat trainset and testset for test size 0.25
trainset, testset = train_test_split(final_data, test_size=0.25)
# fit the trainSet
algo.fit(trainset)

# %%
# test the algo
predictions = algo.test(testset)

# %%
# calculate the accuracy using RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.2895
# 0.28947222967443725

# %%
# evaluate model
from surprise.model_selection import cross_validate

# %%
cross_validate(algo, final_data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.2781  0.2783  0.2801  0.2797  0.2749  0.2782  0.0018
# MAE (testset)     0.0404  0.0402  0.0410  0.0415  0.0409  0.0408  0.0005
# Fit time          66.82   66.77   66.79   68.05   71.64   68.01   1.88
# Test time         2.15    2.45    2.82    2.54    2.43    2.48    0.21
# {'test_rmse': array([0.27808127, 0.27825733, 0.28007764, 0.27972275, 0.27490979]),
#  'test_mae': array([0.04042886, 0.04020518, 0.041034  , 0.04149584, 0.0409266 ]),
#  'fit_time': (66.81780695915222,
#   66.76883506774902,
#   66.79082584381104,
#   68.05404710769653,
#   71.63683652877808),
#  'test_time': (2.149674892425537,
#   2.451490640640259,
#   2.81726336479187,
#   2.5394344329833984,
#   2.429504156112671)}

# %%
from surprise import NormalPredictor
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import SVD
from surprise import BaselineOnly
from surprise import SVDpp
from surprise import NMF
from surprise import SlopeOne
from surprise import CoClustering

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp()]:
    # , SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()
    # Perform cross validation
    results = cross_validate(algorithm, final_data, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
#            test_rmse     fit_time  test_time
# Algorithm
# SVDpp       0.280749  1656.151152  70.517408
# SVD         0.282776    55.187311   4.187085
